# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os

# %%
from model import GeneratorUSRGAN  # Ensure this matches your model definition

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load model
model = GeneratorUSRGAN().to(device)

# %%
# Step 3: Use Fine-Tuned Model for Inference
from torchvision.utils import save_image

# Load fine-tuned model
model.load_state_dict(torch.load("srgan_finetuned_ssim.pth", map_location=device))
model.to(device)
model.eval()

# Define transformation (resize and normalize)
transform = transforms.Compose([
    #transforms.Resize((256, 256)),  # Match training resolution
    transforms.ToTensor()
])

# Load test images

test_images_path = "images"  # Update this if needed
test_images = [f for f in os.listdir(test_images_path) if f.endswith(('.png', '.jpg', '.jpeg'))]

# %%
output_dir = "enhanced_images_all"
os.makedirs(output_dir, exist_ok=True)  # Ensure output directory exists

# Process each image
for img_name in test_images:
    img_path = os.path.join(test_images_path, img_name)
    img = Image.open(img_path).convert("RGB")  # Convert to RGB

    # Apply transformation
    lr_image = transform(img).unsqueeze(0).to(device)  # Add batch dimension

    # Enhance image using the SRGAN model
    with torch.no_grad():
        sr_image = model(lr_image)

    # Convert output tensor to image
    sr_image = sr_image.squeeze(0).cpu().permute(1, 2, 0).numpy()  # Convert to HWC format
    sr_image = ((sr_image + 1) / 2 * 255).astype("uint8")  # Rescale from [-1,1] to [0,255]
    sr_image = Image.fromarray(sr_image)

    # Save enhanced image
    sr_image.save(os.path.join(output_dir, img_name))
    print(f"Saved enhanced image: {img_name}")
# Out:
# Saved enhanced image: FishDataset119_png.rf.5400284ea33a58a61de4f0ae9c380c13.jpg
# Saved enhanced image: FishDataset119_png.rf.qwvSqHU30Lxz48hqM6yg.jpg
# Saved enhanced image: FishDataset12_png.rf.12a2d25995702339cc4f2bf69d58cfaf.jpg
# Saved enhanced image: FishDataset12_png.rf.AFP6H846vTfHF9mRdf6u.jpg
# Saved enhanced image: FishDataset162_png.rf.e9a5507588f1af930a5e3d195026616e.jpg
# Saved enhanced image: FishDataset162_png.rf.wX5frtfXCMiSyLNuhif5.jpg
# Saved enhanced image: FishDataset18_png.rf.39fe8e48b9075f6edbeb115f654f883a.jpg
# Saved enhanced image: FishDataset18_png.rf.CBw2vCaKeDUgCsuX8iTY.jpg
# Saved enhanced image: FishDataset191_png.rf.1893f84914c84986fc8defa499245119.jpg
# Saved enhanced image: FishDataset191_png.rf.gP6I7RhYtZXSPK7gNUS3.jpg
# Saved enhanced image: FishDataset198_png.rf.7392fdef0ea1ac052bece31cea4ca72f.jpg
# Saved enhanced image: FishDataset198_png.rf.nIf9Uqk0shTBrEcDxJzZ.jpg
# Saved enhanced image: FishDataset210_png.rf.aefa3d22bf0bea68a67bf92be1bfe525.jpg
# Saved enhanced image: FishDataset210_png.rf.zHgvOc7R70iNfD54T3Ej.jpg
# Saved enhanced image: FishDataset217_png.rf.e261b10fe317bc2e50229520c2b5c3bf.jpg
# Saved enhanced image: FishDataset217_png.rf.uKz699YMl0OjuyCOtwPk.jpg
# Saved enhanced image: FishDataset221_png.rf.a86a7f943d65ebc378b77111cf75ca39.jpg
# Saved enhanced image: FishDataset221_png.rf.pPFX8fVXUuh2Jm1nodsk.jpg
# Saved enhanced image: FishDataset223_png.rf.335cf10c5756f48fc2a948a9e8a88814.jpg
# Saved enhanced image: FishDataset223_png.rf.BK4JyZrcZet3YdwTKzog.jpg
# Saved enhanced image: FishDataset224_png.rf.badd83d49123974aec51dda48d2b4d7c.jpg
# Saved enhanced image: FishDataset224_png.rf.oWEdaBhUqE8vdBySUxGz.jpg
# Saved enhanced image: FishDataset22_png.rf.6e2a10566caf909c366315c77b3a91b8.jpg
# Saved enhanced image: FishDataset22_png.rf.iXKFuk3kzRwGqdzQS0g0.jpg
# Saved enhanced image: FishDataset238_png.rf.91f7386105c8eb06b5336d71d43dde86.jpg
# Saved enhanced image: FishDataset238_png.rf.pHjwX5G1FTlQnsV6KB9n.jpg
# Saved enhanced image: FishDataset245_png.rf.69ba14a941c83aaffec62df7bcbd666e.jpg
# Saved enhanced image: FishDataset245_png.rf.m04phkDbP33LYUfcFRie.jpg
# Saved enhanced image: FishDataset247_png.rf.73e90ba8c1e5c76fbb462e5f7e8a3c53.jpg
# Saved enhanced image: FishDataset247_png.rf.rORAGWvqtL1zciflv9Dt.jpg
# Saved enhanced image: FishDataset250_png.rf.b3336fbd192b55b804ab0f7ebb95e1ef.jpg
# Saved enhanced image: FishDataset250_png.rf.sHJhExuRM7FqDjUTmuoG.jpg
# Saved enhanced image: FishDataset271_png.rf.5iJSPE5UjnIMrgwPKY7x.jpg
# Saved enhanced image: FishDataset271_png.rf.d9e6cdbc8430721846a44076ee02489f.jpg
# Saved enhanced image: FishDataset273_png.rf.a4cggmKcOWEJW2Brb6sn.jpg
# Saved enhanced image: FishDataset273_png.rf.e20b81f68c043da4d57bbaa095221fce.jpg
# Saved enhanced image: FishDataset277_png.rf.86a74b04e722cb78a56394a887fa3476.jpg
# Saved enhanced image: FishDataset277_png.rf.GgEVSMR15DJfsvaiST4v.jpg
# Saved enhanced image: FishDataset27_png.rf.65fbbf3fb5368285e95c1d35c7ca0175.jpg
# Saved enhanced image: FishDataset27_png.rf.QAFFdZuPhFu4thAkDMsx.jpg
# Saved enhanced image: FishDataset282_png.rf.1a1b3825d9e0cc21d7738e8c85d4770a.jpg
# Saved enhanced image: FishDataset282_png.rf.Nk0GtoMty5pO5X3cb30O.jpg
# Saved enhanced image: FishDataset284_png.rf.a818080f97f879290ca9500828527711.jpg
# Saved enhanced image: FishDataset284_png.rf.UnsyU943kbZoMTCl8tSk.jpg
# Saved enhanced image: FishDataset285_png.rf.30b2d9af784724227bfe722520b8cf91.jpg
# Saved enhanced image: FishDataset285_png.rf.rln2CQ828l8R0iSiQBT9.jpg
# Saved enhanced image: FishDataset286_png.rf.AWi2em94RYlhIQi8sPS0.jpg
# Saved enhanced image: FishDataset286_png.rf.eb5bfd3cbaa614014f820387af2a7a7e.jpg
# Saved enhanced image: FishDataset2_png.rf.a1c8108b4653e9ca7e6252443ee6ec27.jpg
# Saved enhanced image: FishDataset2_png.rf.RsH5vdflAq5CQkI7IpD5.jpg
# Saved enhanced image: FishDataset333_png.rf.96ebf3660961d63c7a02ef0e210e20f5.jpg
# Saved enhanced image: FishDataset333_png.rf.YxwRwudpGgdsRuguHEg4.jpg
# Saved enhanced image: FishDataset33_png.rf.c48aaa175cbe1ec6c98bd705a9fa1b16.jpg
# Saved enhanced image: FishDataset33_png.rf.zsHZZDjMqsGahiV4KnIg.jpg
# Saved enhanced image: FishDataset352_png.rf.068edb9ed4ce4366eb5f6c566afe7393.jpg
# Saved enhanced image: FishDataset352_png.rf.BFjwM7ffmVBKciL1yyag.jpg
# Saved enhanced image: FishDataset357_png.rf.d0f7b8ae25d6565024c97ff9774a3977.jpg
# Saved enhanced image: FishDataset357_png.rf.hcom7rKYssNywyrlcoFV.jpg
# Saved enhanced image: FishDataset374_png.rf.02d3700ca717ba6e2788f328fc6f59a5.jpg
# Saved enhanced image: FishDataset374_png.rf.qQaKOi97VokjlhJ6HV4I.jpg
# Saved enhanced image: FishDataset382_png.rf.491ef3840d3a0618bb29307ccb012e3a.jpg
# Saved enhanced image: FishDataset382_png.rf.tEucIyiKfk8d7QAWPyvU.jpg
# Saved enhanced image: FishDataset412_png.rf.6785c3accd24918f13f20923147a61a6.jpg
# Saved enhanced image: FishDataset412_png.rf.Hcaqz6jhn1gBVa4L1SoN.jpg
# Saved enhanced image: FishDataset415_png.rf.9a799904f843777f049cfcf8b7a0c077.jpg
# Saved enhanced image: FishDataset415_png.rf.w4o9w4kBgpq2EBUNZVmM.jpg
# Saved enhanced image: FishDataset431_png.rf.aec455e6aabe7b8fb77760dd9923c5b8.jpg
# Saved enhanced image: FishDataset431_png.rf.gYA7ZUN6d397osxg57UN.jpg
# Saved enhanced image: FishDataset441_png.rf.a3871c7df1f3d97c9df4f0a8d9071449.jpg
# Saved enhanced image: FishDataset441_png.rf.i8mRBui1HzmTZ5wSHvcv.jpg
# Saved enhanced image: FishDataset443_png.rf.9dabe1e7eaf92c0266e9011234b82836.jpg
# Saved enhanced image: FishDataset443_png.rf.KqKJuCtcoOsrA3f9UAF6.jpg
# Saved enhanced image: FishDataset461_png.rf.1b3bcba7bfdf8343bf549ef7a201b9d7.jpg
# Saved enhanced image: FishDataset461_png.rf.rGoPnIYzsHzLVnXpaqps.jpg
# Saved enhanced image: FishDataset465_png.rf.139bc0c92b89c8981bb049c1a745c386.jpg
# Saved enhanced image: FishDataset465_png.rf.gOZ15KnhtcfELZASNNgj.jpg
# Saved enhanced image: FishDataset489_png.rf.6djM6vZqsJx1rzWHWlW2.jpg
# Saved enhanced image: FishDataset489_png.rf.7491ed4407e4ba7af1a8ec418e8ed23f.jpg
# Saved enhanced image: FishDataset495_png.rf.aEvk0eZm29JQjdFoTV93.jpg
# Saved enhanced image: FishDataset495_png.rf.d3a5acfafc23660b97cf1c801166e9d1.jpg
# Saved enhanced image: FishDataset496_png.rf.99ecbfc28270ebfe38c5a6ff6257bb8c.jpg
# Saved enhanced image: FishDataset496_png.rf.HfKM5QVD5uiIG682p8PX.jpg
# Saved enhanced image: FishDataset49_png.rf.cbb5869c364c9f57a6bc51f21527c1ee.jpg
# Saved enhanced image: FishDataset49_png.rf.GCBpxJWDw3jHVoq5mNx1.jpg
# Saved enhanced image: FishDataset508_png.rf.77473a5edb1e3e4dfcadd14806734842.jpg
# Saved enhanced image: FishDataset508_png.rf.oCK92wsjYa667MRX7iDv.jpg
# Saved enhanced image: FishDataset515_png.rf.db58ae920767abec5666c9a273ddd16f.jpg
# Saved enhanced image: FishDataset515_png.rf.ecpVHINXoDi6t3VMrO6A.jpg
# Saved enhanced image: FishDataset523_png.rf.cSy72H1YFccGQA1cuSqT.jpg
# Saved enhanced image: FishDataset523_png.rf.f28e241ec3397eb05e00532842f54324.jpg
# Saved enhanced image: FishDataset528_png.rf.666f0a15bff7cd93bbc71742348ed56f.jpg
# Saved enhanced image: FishDataset528_png.rf.EYDw3BMcZhIYoyy3aKUK.jpg
# Saved enhanced image: FishDataset531_png.rf.65a496e3c95d9249ea8d0faa05a92b2b.jpg
# Saved enhanced image: FishDataset531_png.rf.kzb7s1Jqu5op3ZWPU4kZ.jpg
# Saved enhanced image: FishDataset534_png.rf.e5fb5b7180b7522ef1c7ccfb07414e18.jpg
# Saved enhanced image: FishDataset534_png.rf.HCWHnmQnxaIXbFdTSkmU.jpg
# Saved enhanced image: FishDataset555_png.rf.6633245390888abe8fea825006965510.jpg
# Saved enhanced image: FishDataset555_png.rf.DPb7HFT3CYtHutkuSr6V.jpg
# Saved enhanced image: FishDataset564_png.rf.74d01a20e9895bb3f64dff7a85db6585.jpg
# Saved enhanced image: FishDataset564_png.rf.P0HFl33S4yhAMEpBI1hK.jpg
# Saved enhanced image: FishDataset567_png.rf.aedaca2aa2a8b4bc32f9e42dba179eea.jpg
# Saved enhanced image: FishDataset567_png.rf.CVbvvWeFqJhvRmZxVYlC.jpg
# Saved enhanced image: FishDataset586_png.rf.0615b3457f4321b75ee7dd3c0c739a3a.jpg
# Saved enhanced image: FishDataset586_png.rf.BEfnYeKG4XsBjDzp7QMj.jpg
# Saved enhanced image: FishDataset592_png.rf.8iEBvqiijRo561dKnLsF.jpg
# Saved enhanced image: FishDataset592_png.rf.c754e8edcc7879437e824bc970a89717.jpg
# Saved enhanced image: FishDataset606_png.rf.d7c1a3271dc4fd82a979e8e7d6f77af4.jpg
# Saved enhanced image: FishDataset606_png.rf.T6kLtB0fMyj8rt8juZfd.jpg
# Saved enhanced image: FishDataset618_png.rf.6f00c98d79be2d06f4d302d8d27bdb81.jpg
# Saved enhanced image: FishDataset618_png.rf.7BVZZwyPeU1Jx2KvwSIj.jpg
# Saved enhanced image: FishDataset61_png.rf.759b376519d83f452573e7e51d8d9cf3.jpg
# Saved enhanced image: FishDataset61_png.rf.SNZJRDtTGIhQ4iXEnfOU.jpg
# Saved enhanced image: FishDataset63_png.rf.b025f86f7a74c2c1e02abaf722a691b4.jpg
# Saved enhanced image: FishDataset63_png.rf.jlcobUdzoquiBR3Qh3vy.jpg
# Saved enhanced image: FishDataset647_png.rf.ebb4ee3759d2fd2e86c10a18417f6849.jpg
# Saved enhanced image: FishDataset647_png.rf.V9Ev8L13lmxnZ4oR6xVk.jpg
# Saved enhanced image: FishDataset648_png.rf.cf77a26cb7f7297cd9e11470cf3f7d27.jpg
# Saved enhanced image: FishDataset648_png.rf.M2J59fRG1nzuSFLTzL7v.jpg
# Saved enhanced image: FishDataset650_png.rf.0a14f4401f6beedde7c2807f49850098.jpg
# Saved enhanced image: FishDataset650_png.rf.wZ2CHyMe5yDuPhqCORNk.jpg
# Saved enhanced image: FishDataset662_png.rf.3560b3c4fef6eee49cb79df89298c88d.jpg
# Saved enhanced image: FishDataset662_png.rf.NEl3f23MIAvV4j8HDfga.jpg
# Saved enhanced image: FishDataset689_png.rf.5740179a69022d7b20d4641084c9839b.jpg
# Saved enhanced image: FishDataset689_png.rf.UwlR0UUJiTPeWBvshLmq.jpg
# Saved enhanced image: FishDataset704_png.rf.77162ab5ea28a84da466eca1aa8ceb6d.jpg
# Saved enhanced image: FishDataset704_png.rf.UWi5fDWDxYbY3SWQnA3X.jpg
# Saved enhanced image: FishDataset705_png.rf.79ee0380c14912e589527b4e22fcb3cd.jpg
# Saved enhanced image: FishDataset705_png.rf.ZkxZRDzgbZ2TK02lb4qp.jpg
# Saved enhanced image: FishDataset714_png.rf.9536a881bf9335aca585d0f3a7c099bb.jpg
# Saved enhanced image: FishDataset714_png.rf.TqmkGTwC9EVCdUzMa6k6.jpg
# Saved enhanced image: FishDataset82_png.rf.225b7131127d4dec8a6268196749ac64.jpg
# Saved enhanced image: FishDataset82_png.rf.vbvIJcpBlpV7yRYSkMBo.jpg
# Saved enhanced image: FishDataset87_png.rf.20bcb50d4e1ce3af24da16c8f7bf6062.jpg
# Saved enhanced image: FishDataset87_png.rf.4R63lkzqlLIDl1Li42yb.jpg
# Saved enhanced image: FishDataset97_png.rf.0bb11163a08456dfaf69c8cfa24877e7.jpg
# Saved enhanced image: FishDataset97_png.rf.paAi5x2V9rw0Ocph7DiQ.jpg
